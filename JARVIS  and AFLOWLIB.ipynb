# %% [markdown]
# # JARVIS-Tools
#
# # About
#
# The JARVIS-Tools is an open-access software package for atomistic data-driven materials desgin. JARVIS-Tools can be used for:
#
# a) setting up calculations, b) analysis and informatics, c) plotting, d) database development, e) machine-learning, and f) web-page development.
#
# https://jarvis.nist.gov

# %% [markdown]
# # To install JARVIS-Tools

# %%
# !pip install jarvis-tools
# Out:
# Collecting jarvis-tools
#   Downloading jarvis_tools-2022.5.20-py2.py3-none-any.whl (962 kB)
#      |████████████████████████████████| 962 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.0.0 in /home/jp/.local/lib/python3.8/site-packages (from jarvis-tools) (3.5.1)
# Requirement already satisfied: spglib>=1.14.1 in /home/jp/.local/lib/python3.8/site-packages (from jarvis-tools) (1.16.3)
# Requirement already satisfied: requests>=2.23.0 in /home/jp/.local/lib/python3.8/site-packages (from jarvis-tools) (2.27.1)
# Requirement already satisfied: scipy>=1.4.1 in /home/jp/.local/lib/python3.8/site-packages (from jarvis-tools) (1.8.0)
# Collecting xmltodict>=0.11.0
#   Using cached xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: tqdm>=4.41.1 in /home/jp/.local/lib/python3.8/site-packages (from jarvis-tools) (4.64.0)
# Collecting toolz>=0.9.0
#   Using cached toolz-0.11.2-py3-none-any.whl (55 kB)
# Requirement already satisfied: joblib>=0.14.1 in /home/jp/.local/lib/python3.8/site-packages (from jarvis-tools) (1.1.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/jp/.local/lib/python3.8/site-packages (from jarvis-tools) (1.22.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jp/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->jarvis-tools) (4.31.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=3.0.0->jarvis-tools) (7.0.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jp/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->jarvis-tools) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jp/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->jarvis-tools) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jp/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->jarvis-tools) (3.0.7)
# Requirement already satisfied: packaging>=20.0 in /home/jp/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->jarvis-tools) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/jp/.local/lib/python3.8/site-packages (from matplotlib>=3.0.0->jarvis-tools) (0.11.0)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /usr/lib/python3/dist-packages (from requests>=2.23.0->jarvis-tools) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.23.0->jarvis-tools) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.23.0->jarvis-tools) (2019.11.28)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /home/jp/.local/lib/python3.8/site-packages (from requests>=2.23.0->jarvis-tools) (2.0.12)
# Requirement already satisfied: six>=1.5 in /home/jp/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->jarvis-tools) (1.16.0)
# Installing collected packages: xmltodict, toolz, jarvis-tools
# Successfully installed jarvis-tools-2022.5.20 toolz-0.11.2 xmltodict-0.13.0

# %% [markdown]
# # Download dft dataset and print available keys, print dataset size.

# %%
from jarvis.db.figshare import data

d = data('dft_3d') 

# See available keys
print(d[0].keys())

# Dataset size
print(len(d))
# Out:
# Obtaining 3D dataset 55k ...
# Reference:https://www.nature.com/articles/s41524-020-00440-1
# 100%|█████████████████████████████████████| 31.9M/31.9M [12:47<00:00, 41.6kiB/s]
# Loading the zipfile...
# Loading completed.
# dict_keys(['jid', 'spg_number', 'spg_symbol', 'formula', 'formation_energy_peratom', 'func', 'optb88vdw_bandgap', 'atoms', 'slme', 'magmom_oszicar', 'spillage', 'elastic_tensor', 'effective_masses_300K', 'kpoint_length_unit', 'maxdiff_mesh', 'maxdiff_bz', 'encut', 'optb88vdw_total_energy', 'epsx', 'epsy', 'epsz', 'mepsx', 'mepsy', 'mepsz', 'modes', 'magmom_outcar', 'max_efg', 'avg_elec_mass', 'avg_hole_mass', 'icsd', 'dfpt_piezo_max_eij', 'dfpt_piezo_max_dij', 'dfpt_piezo_max_dielectric', 'dfpt_piezo_max_dielectric_electronic', 'dfpt_piezo_max_dielectric_ionic', 'max_ir_mode', 'min_ir_mode', 'n-Seebeck', 'p-Seebeck', 'n-powerfact', 'p-powerfact', 'ncond', 'pcond', 'nkappa', 'pkappa', 'ehull', 'dimensionality', 'efg', 'xml_data_link', 'typ', 'exfoliation_energy', 'spg', 'crys', 'density', 'poisson', 'raw_files', 'nat', 'bulk_modulus_kv', 'shear_modulus_gv', 'mbj_bandgap', 'hse_gap', 'reference', 'search'])
# 55723

# %% [markdown]
# # Visualize an atoms object

# %%
from jarvis.core.atoms import Atoms
a = Atoms.from_dict(d[0]['atoms'])

#You can visualize this in VESTA or other similar packages
print(a)
# Out:
# Ti2Cu2Si2As2
# 1.0
# 3.566933224304235 0.0 -0.0
# 0.0 3.566933224304235 -0.0
# -0.0 -0.0 9.397075454186664
# Ti Cu Si As
# 2 2 2 2
# Cartesian
# 2.6751975000000003 2.6751975000000003 7.376101754328542
# 0.8917325 0.8917325 2.0209782456714573
# 0.8917325 2.6751975000000003 4.69854
# 2.6751975000000003 0.8917325 4.69854
# 0.8917325 2.6751975000000003 0.0
# 2.6751975000000003 0.8917325 0.0
# 2.6751975000000003 2.6751975000000003 2.8894795605846353
# 0.8917325 0.8917325 6.507600439415366

# %% [markdown]
# # Pandas
# pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.
#
# # Load our dft dataset into pandas dataframe.

# %%
import pandas as pd

df = pd.DataFrame(d)

print(df)
# Out:
#                 jid spg_number spg_symbol      formula  \
# 0       JVASP-90856        129     P4/nmm     TiCuSiAs
# 1       JVASP-86097        221      Pm-3m         DyB6
# 2       JVASP-64906        119      I-4m2      Be2OsRu
# 3       JVASP-98225         14     P2_1/c          KBi
# 4          JVASP-10        164      P-3m1         VSe2
# ...             ...        ...        ...          ...
# 55718  JVASP-123206        164      P-3m1        HeEr3
# 55719  JVASP-122142        191     P6/mmm  ZrMn6Ga2Sn4
# 55720  JVASP-123207        164      P-3m1        Er3Hf
# 55721  JVASP-121802          2        P-1       SbPbF7
# 55722  JVASP-123937        187      P-6m2         LiMg
#
#        formation_energy_peratom       func  optb88vdw_bandgap  \
# 0                      -0.42762  OptB88vdW              0.000
# 1                      -0.41596  OptB88vdW              0.000
# 2                       0.04847  OptB88vdW              0.000
# 3                      -0.44140  OptB88vdW              0.472
# 4                      -0.71026  OptB88vdW              0.000
# ...                         ...        ...                ...
# 55718                   0.37366  OptB88vdW              0.000
# 55719                  -0.01992  OptB88vdW              0.000
# 55720                   0.07529  OptB88vdW              0.000
# 55721                  -2.45757  OptB88vdW              3.652
# 55722                  -0.08259  OptB88vdW              0.000
#
#                                                    atoms slme magmom_oszicar  \
# 0      {'lattice_mat': [[3.566933224304235, 0.0, -0.0...   na            0.0
# 1      {'lattice_mat': [[4.089078911208881, 0.0, 0.0]...   na            0.0
# 2      {'lattice_mat': [[-1.833590720595598, 1.833590...   na            0.0
# 3      {'lattice_mat': [[7.2963518353359165, 0.0, 0.0...   na            0.0
# 4      {'lattice_mat': [[1.6777483798834445, -2.90594...   na            0.0
# ...                                                  ...  ...            ...
# 55718  {'lattice_mat': [[3.430088850824678, 1.7386541...   na            0.0
# 55719  {'lattice_mat': [[5.2820419621666534, -3.15118...   na             na
# 55720  {'lattice_mat': [[3.3925352656525147, 2.202105...   na            0.0
# 55721  {'lattice_mat': [[4.628095666847773, -0.007449...   na            0.0
# 55722  {'lattice_mat': [[1.5498564480003332, -2.68443...   na            0.0
#
#        ... density poisson                                          raw_files  \
# 0      ...   5.956      na                                                 []
# 1      ...   5.522      na  [OPT-LOPTICS,JVASP-86097.zip,https://ndownload...
# 2      ...  10.960      na  [OPT-LOPTICS,JVASP-64906.zip,https://ndownload...
# 3      ...   5.145      na                                                 []
# 4      ...   5.718    0.23  [FD-ELAST,JVASP-10.zip,https://ndownloader.fig...
# ...    ...     ...     ...                                                ...
# 55718  ...   6.451      na                                                 []
# 55719  ...   7.933      na                                                 []
# 55720  ...  10.357      na                                                 []
# 55721  ...   6.077      na                                                 []
# 55722  ...   1.242      na                                                 []
#
#       nat bulk_modulus_kv shear_modulus_gv mbj_bandgap  hse_gap  \
# 0       8              na               na          na       na
# 1       7              na               na          na       na
# 2       4              na               na          na       na
# 3      32              na               na          na       na
# 4       3           48.79            33.05         0.0       na
# ...    ..             ...              ...         ...      ...
# 55718   4              na               na          na       na
# 55719  13              na               na          na       na
# 55720   4              na               na          na       na
# 55721  18              na               na          na       na
# 55722   2              na               na          na       na
#
#                    reference        search
# 0                 mp-1080455  -As-Cu-Si-Ti
# 1                  mp-568319         -B-Dy
# 2      auid-3eaf68dd483bf4f4     -Be-Os-Ru
# 3                   mp-31104         -Bi-K
# 4                     mp-694         -Se-V
# ...                      ...           ...
# 55718           JVASP-102277        -Er-He
# 55719             mp-1215332  -Ga-Mn-Sn-Zr
# 55720           JVASP-102277        -Er-Hf
# 55721             mp-1105453      -F-Pb-Sb
# 55722              JVASP-919        -Li-Mg
#
# [55723 rows x 63 columns]

# %% [markdown]
# # Print all the columns.

# %%
pd.set_option('display.max_columns', None)

#If you just want to see the column names you can do

#print(df.columns.tolist())

df
# Out:
#                 jid spg_number spg_symbol      formula  \
# 0       JVASP-90856        129     P4/nmm     TiCuSiAs
# 1       JVASP-86097        221      Pm-3m         DyB6
# 2       JVASP-64906        119      I-4m2      Be2OsRu
# 3       JVASP-98225         14     P2_1/c          KBi
# 4          JVASP-10        164      P-3m1         VSe2
# ...             ...        ...        ...          ...
# 55718  JVASP-123206        164      P-3m1        HeEr3
# 55719  JVASP-122142        191     P6/mmm  ZrMn6Ga2Sn4
# 55720  JVASP-123207        164      P-3m1        Er3Hf
# 55721  JVASP-121802          2        P-1       SbPbF7
# 55722  JVASP-123937        187      P-6m2         LiMg
#
#        formation_energy_peratom       func  optb88vdw_bandgap  \
# 0                      -0.42762  OptB88vdW              0.000
# 1                      -0.41596  OptB88vdW              0.000
# 2                       0.04847  OptB88vdW              0.000
# 3                      -0.44140  OptB88vdW              0.472
# 4                      -0.71026  OptB88vdW              0.000
# ...                         ...        ...                ...
# 55718                   0.37366  OptB88vdW              0.000
# 55719                  -0.01992  OptB88vdW              0.000
# 55720                   0.07529  OptB88vdW              0.000
# 55721                  -2.45757  OptB88vdW              3.652
# 55722                  -0.08259  OptB88vdW              0.000
#
#                                                    atoms slme magmom_oszicar  \
# 0      {'lattice_mat': [[3.566933224304235, 0.0, -0.0...   na            0.0
# 1      {'lattice_mat': [[4.089078911208881, 0.0, 0.0]...   na            0.0
# 2      {'lattice_mat': [[-1.833590720595598, 1.833590...   na            0.0
# 3      {'lattice_mat': [[7.2963518353359165, 0.0, 0.0...   na            0.0
# 4      {'lattice_mat': [[1.6777483798834445, -2.90594...   na            0.0
# ...                                                  ...  ...            ...
# 55718  {'lattice_mat': [[3.430088850824678, 1.7386541...   na            0.0
# 55719  {'lattice_mat': [[5.2820419621666534, -3.15118...   na             na
# 55720  {'lattice_mat': [[3.3925352656525147, 2.202105...   na            0.0
# 55721  {'lattice_mat': [[4.628095666847773, -0.007449...   na            0.0
# 55722  {'lattice_mat': [[1.5498564480003332, -2.68443...   na            0.0
#
#       spillage                                     elastic_tensor  \
# 0           na                                                 na
# 1           na                                                 na
# 2           na                                                 na
# 3           na                                                 na
# 4           na  [[136.4, 27.8, 17.5, 0.0, -5.5, 0.0], [27.8, 1...
# ...        ...                                                ...
# 55718       na                                                 na
# 55719       na                                                 na
# 55720       na                                                 na
# 55721       na                                                 na
# 55722       na                                                 na
#
#                               effective_masses_300K kpoint_length_unit  \
# 0                            {'p': 'na', 'n': 'na'}                 60
# 1                            {'p': 'na', 'n': 'na'}                 65
# 2                            {'p': 'na', 'n': 'na'}                 60
# 3                            {'p': 'na', 'n': 'na'}                 40
# 4      {'p': [0.0, 0.0, 0.0], 'n': [0.0, 0.0, 0.0]}                 40
# ...                                             ...                ...
# 55718                        {'p': 'na', 'n': 'na'}                 35
# 55719                        {'p': 'na', 'n': 'na'}                 30
# 55720                        {'p': 'na', 'n': 'na'}                 25
# 55721                        {'p': 'na', 'n': 'na'}                 25
# 55722                        {'p': 'na', 'n': 'na'}                 75
#
#       maxdiff_mesh maxdiff_bz encut  optb88vdw_total_energy      epsx  \
# 0               na         na   650                -3.37474     76.23
# 1               na         na  1000                -5.79186  140.9742
# 2               na         na  1100                -4.65924  215.4488
# 3               na         na   500                -0.42496        na
# 4               na         na   500                -3.87823    47.029
# ...            ...        ...   ...                     ...       ...
# 55718           na         na   500                -0.83133   28.8448
# 55719           na         na   500                -3.14550        na
# 55720           na         na   500                -3.11208   12.3019
# 55721           na         na   500                -2.57911        na
# 55722           na         na   500                 0.02138   19.2347
#
#            epsy      epsz   mepsx    mepsy   mepsz  \
# 0         76.23   54.0402      na       na      na
# 1      140.9742  140.9742      na       na      na
# 2      215.4488  159.4368      na       na      na
# 3            na        na      na       na      na
# 4        47.029   28.1625  79.071  78.7247  18.006
# ...         ...       ...     ...      ...     ...
# 55718   28.8448    31.924      na       na      na
# 55719        na        na      na       na      na
# 55720   12.3019    5.2488      na       na      na
# 55721        na        na      na       na      na
# 55722   19.2347   15.1285      na       na      na
#
#                                                    modes magmom_outcar  \
# 0                                                     na           0.0
# 1                                                     na           0.0
# 2                                                     na           0.0
# 3                                                     na           0.0
# 4      [-0.22, -0.1, -0.1, 142.22, 142.22, 192.04, 19...           0.0
# ...                                                  ...           ...
# 55718                                                 na           0.0
# 55719                                                 na        12.861
# 55720                                                 na           0.0
# 55721                                                 na           0.0
# 55722                                                 na           0.0
#
#       max_efg avg_elec_mass avg_hole_mass                        icsd  \
# 0          na            na            na
# 1          na            na            na        613601,613595,150623
# 2       23.94            na            na
# 3          na            na            na                       55065
# 4      89.678           0.0           0.0  86520,652160,652163,652158
# ...       ...           ...           ...                         ...
# 55718      na            na            na
# 55719      na            na            na
# 55720      na            na            na
# 55721      na            na            na
# 55722      na            na            na
#
#       dfpt_piezo_max_eij dfpt_piezo_max_dij dfpt_piezo_max_dielectric  \
# 0                     na                 na                        na
# 1                     na                 na                        na
# 2                     na                 na                        na
# 3                     na                 na                        na
# 4                    0.0                0.0                 54.202007
# ...                  ...                ...                       ...
# 55718                 na                 na                        na
# 55719                 na                 na                        na
# 55720                 na                 na                        na
# 55721                 na                 na                        na
# 55722                 na                 na                        na
#
#       dfpt_piezo_max_dielectric_electronic dfpt_piezo_max_dielectric_ionic  \
# 0                                       na                              na
# 1                                       na                              na
# 2                                       na                              na
# 3                                       na                              na
# 4                                44.924312                        9.277695
# ...                                    ...                             ...
# 55718                                   na                              na
# 55719                                   na                              na
# 55720                                   na                              na
# 55721                                   na                              na
# 55722                                   na                              na
#
#       max_ir_mode min_ir_mode  n-Seebeck  p-Seebeck n-powerfact p-powerfact  \
# 0              na          na         na         na          na          na
# 1              na          na         na         na          na          na
# 2              na          na         na         na          na          na
# 3              na          na         na         na          na          na
# 4          342.84      204.14  18.273333  17.486667      657.17  614.083333
# ...           ...         ...        ...        ...         ...         ...
# 55718          na          na         na         na          na          na
# 55719          na          na         na         na          na          na
# 55720          na          na         na         na          na          na
# 55721          na          na         na         na          na          na
# 55722          na          na         na         na          na          na
#
#                 ncond           pcond              nkappa              pkappa  \
# 0                  na              na                  na                  na
# 1                  na              na                  na                  na
# 2                  na              na                  na                  na
# 3                  na              na                  na                  na
# 4      2033190.976667  2045950.983333  2798132623333333.0  2811808060000000.0
# ...               ...             ...                 ...                 ...
# 55718              na              na                  na                  na
# 55719              na              na                  na                  na
# 55720              na              na                  na                  na
# 55721              na              na                  na                  na
# 55722              na              na                  na                  na
#
#           ehull    dimensionality  \
# 0      2.103442           3D-bulk
# 1      4.548492           3D-bulk
# 2      3.542902  intercalated ion
# 3      0.160275  intercalated ion
# 4       1.87523           2D-bulk
# ...         ...               ...
# 55718        na                na
# 55719        na                na
# 55720        na                na
# 55721        na                na
# 55722        na                na
#
#                                                      efg  \
# 0                                                     []
# 1                                                     []
# 2      [[Be, a, -1.504, 0.001, 0.001, 0.001, -1.504, ...
# 3                                                     []
# 4      [[V, a, 22.568, 0.0, 0.0, 0.0, 22.559, 0.0, 0....
# ...                                                  ...
# 55718                                                 []
# 55719                                                 []
# 55720                                                 []
# 55721                                                 []
# 55722                                                 []
#
#                                            xml_data_link   typ  \
# 0      <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 1      <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 2      <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 3      <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 4      <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# ...                                                  ...   ...
# 55718  <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 55719  <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 55720  <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 55721  <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
# 55722  <a href=https://www.ctcms.nist.gov/~knc6/stati...  bulk
#
#       exfoliation_energy  spg        crys  density poisson  \
# 0                     na  129  tetragonal    5.956      na
# 1                     na  221       cubic    5.522      na
# 2                     na  119  tetragonal   10.960      na
# 3                     na   14  monoclinic    5.145      na
# 4                  83.78  164    trigonal    5.718    0.23
# ...                  ...  ...         ...      ...     ...
# 55718                 na  164    trigonal    6.451      na
# 55719                 na  191   hexagonal    7.933      na
# 55720                 na  164    trigonal   10.357      na
# 55721                 na    2   triclinic    6.077      na
# 55722                 na  187   hexagonal    1.242      na
#
#                                                raw_files  nat bulk_modulus_kv  \
# 0                                                     []    8              na
# 1      [OPT-LOPTICS,JVASP-86097.zip,https://ndownload...    7              na
# 2      [OPT-LOPTICS,JVASP-64906.zip,https://ndownload...    4              na
# 3                                                     []   32              na
# 4      [FD-ELAST,JVASP-10.zip,https://ndownloader.fig...    3           48.79
# ...                                                  ...  ...             ...
# 55718                                                 []    4              na
# 55719                                                 []   13              na
# 55720                                                 []    4              na
# 55721                                                 []   18              na
# 55722                                                 []    2              na
#
#       shear_modulus_gv mbj_bandgap hse_gap              reference  \
# 0                   na          na      na             mp-1080455
# 1                   na          na      na              mp-568319
# 2                   na          na      na  auid-3eaf68dd483bf4f4
# 3                   na          na      na               mp-31104
# 4                33.05         0.0      na                 mp-694
# ...                ...         ...     ...                    ...
# 55718               na          na      na           JVASP-102277
# 55719               na          na      na             mp-1215332
# 55720               na          na      na           JVASP-102277
# 55721               na          na      na             mp-1105453
# 55722               na          na      na              JVASP-919
#
#              search
# 0      -As-Cu-Si-Ti
# 1             -B-Dy
# 2         -Be-Os-Ru
# 3             -Bi-K
# 4             -Se-V
# ...             ...
# 55718        -Er-He
# 55719  -Ga-Mn-Sn-Zr
# 55720        -Er-Hf
# 55721      -F-Pb-Sb
# 55722        -Li-Mg
#
# [55723 rows x 63 columns]

# %% [markdown]
# # Drop the unnecessary columns.

# %%
df2 = df.drop(['jid', 'spg_number', 'spg_symbol', 'formation_energy_peratom', 'func', 'atoms', 'slme', 'magmom_oszicar', 'spillage', 'elastic_tensor', 'effective_masses_300K', 'kpoint_length_unit', 'maxdiff_mesh', 'maxdiff_bz', 'encut', 'optb88vdw_total_energy', 'epsx', 'epsy', 'epsz', 'mepsx', 'mepsy', 'mepsz', 'modes', 'magmom_outcar', 'max_efg', 'avg_elec_mass', 'avg_hole_mass', 'icsd', 'dfpt_piezo_max_eij', 'dfpt_piezo_max_dij', 'dfpt_piezo_max_dielectric', 'dfpt_piezo_max_dielectric_electronic', 'dfpt_piezo_max_dielectric_ionic', 'max_ir_mode', 'min_ir_mode', 'n-powerfact', 'p-powerfact', 'ehull', 'dimensionality', 'efg', 'xml_data_link', 'typ', 'exfoliation_energy', 'spg', 'crys', 'density', 'poisson', 'raw_files', 'nat', 'bulk_modulus_kv', 'shear_modulus_gv', 'hse_gap', 'reference', 'search'], axis=1)

df2
# Out:
#           formula  optb88vdw_bandgap n-Seebeck p-Seebeck ncond pcond nkappa  \
# 3             KBi              0.472        na        na    na    na     na
# 9       MoW3Se2S6              0.689        na        na    na    na     na
# 19      Mo3WSe6S2              0.502        na        na    na    na     na
# 21          BaGe2              0.560        na        na    na    na     na
# 26            SiS              0.658        na        na    na    na     na
# ...           ...                ...       ...       ...   ...   ...    ...
# 55547        Na3P              0.113        na        na    na    na     na
# 55626        AuOF              0.368        na        na    na    na     na
# 55649       RbAuS              0.240        na        na    na    na     na
# 55652      RbAuS2              0.546        na        na    na    na     na
# 55685  Ca2GaSi2O7              0.223        na        na    na    na     na
#
#       pkappa mbj_bandgap
# 3         na          na
# 9         na          na
# 19        na          na
# 21        na          na
# 26        na       0.959
# ...      ...         ...
# 55547     na          na
# 55626     na          na
# 55649     na          na
# 55652     na       1.197
# 55685     na          na
#
# [4279 rows x 9 columns]

# %% [markdown]
# # Remove rows based on bandgap values.

# %%
df2.drop(df2[df2['optb88vdw_bandgap'] >= 0.8].index)
df2.drop(df2[df2['optb88vdw_bandgap'] <= 0.1].index)
# Out:
#           formula  optb88vdw_bandgap n-Seebeck p-Seebeck ncond pcond nkappa  \
# 3             KBi              0.472        na        na    na    na     na
# 9       MoW3Se2S6              0.689        na        na    na    na     na
# 19      Mo3WSe6S2              0.502        na        na    na    na     na
# 21          BaGe2              0.560        na        na    na    na     na
# 26            SiS              0.658        na        na    na    na     na
# ...           ...                ...       ...       ...   ...   ...    ...
# 55547        Na3P              0.113        na        na    na    na     na
# 55626        AuOF              0.368        na        na    na    na     na
# 55649       RbAuS              0.240        na        na    na    na     na
# 55652      RbAuS2              0.546        na        na    na    na     na
# 55685  Ca2GaSi2O7              0.223        na        na    na    na     na
#
#       pkappa mbj_bandgap
# 3         na          na
# 9         na          na
# 19        na          na
# 21        na          na
# 26        na       0.959
# ...      ...         ...
# 55547     na          na
# 55626     na          na
# 55649     na          na
# 55652     na       1.197
# 55685     na          na
#
# [4268 rows x 9 columns]

# %% [markdown]
# # AFLOW
#
# A repository of computational materials databases constructed from HT ab initio calculations using the AFLOW framework.

# %% [markdown]
# # To get URL, Compound and bandgap (0.1eV - 0.8eV)

# %%
# %%capture cap --no-stderr #To capture the output of this shell.

import json, sys, os
from urllib.request import urlopen

server = "http://aflowlib.org" #Aflow web address.
api = "/API/aflux/?"      
match = "Egap(0.1*,*0.8)"  #Bandgap values.
directives = "$paging(1,4635)"  #Total compounds available for the above bandgap values.
summons = match+","+directives

response = json.loads(urlopen(server+api+summons).read().decode("utf-8")) 

for datum in response:
    bandgap = datum["Egap"]
    compound = datum["compound"]
    print("{},{},{}".format(datum['aurl'],compound,bandgap))

# %% [markdown]
# # Save the response in a text file.

# %%
with open('output.txt', 'w') as f:
    f.write(cap.stdout)
f.close()

# %% [markdown]
# # Edit our output.txt file.

# %%
#Find ":" and replace it with "/"

#input file
f_in = open("output.txt", "rt")

#output file to write the result to
f_out = open("output_1.txt", "wt")

#for each line in the input file
for line in f_in:

#read replace the string and write to output file
    f_out.write(line.replace(':', '/'))

#close input and output files
f_in.close()
f_out.close()

# %% [markdown]
# # Download cif files.
#
# All the 4635 files can be downloaded.

# %%
#To download all the files from the output.txt with their serving name.

#!wget --content-disposition -i /home/Jarvis/Dropbox/output.txt

# %% [markdown]
# # Convert cif files into VASP poscar format.

# %%
#https://github.com/tamaswells/VASP_script/blob/master/cif2poscar/cif2pos.py
